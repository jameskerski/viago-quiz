# %% [markdown]
# # VIAGO interim question-bank coverage analysis
#
# Reproduces the aggregate profile, context/domain coverage, lexical-similarity screen, and repeat-exposure projection for 151 active questions plus 40 OWNER-reviewed development candidates. This notebook does not connect to or mutate production.

# %%
from pathlib import Path
import runpy

root = Path.cwd().resolve()
if not (root / 'scripts/v2/analyze-interim-coverage.py').exists():
    root = root.parent
runpy.run_path(str(root / 'scripts/v2/analyze-interim-coverage.py'), run_name='__main__')

# %%
import json

result = json.loads((root / 'data/v2-analysis/interim-coverage.json').read_text())
result['counts'], result['color_measurement_opportunities'], result['repeat_exposure_projection']
